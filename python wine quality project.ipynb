# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Summary statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [raw]
# key observations:
#
#     the mean is more than median (50th percentile)in all columns
#     there is large difference in 75% percentile and max in residual sugar,free sulphur dioxide and total sulfur dioxide
#     the 1 and 2 observations suggest that there are extreme outliers present in these three columns

# %% [markdown]
# # exploring data variables

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [raw]
# target/dependent variable is discrete and categorical in nature
#
# quality score scale ranges from 1 to 10
# where 1 is low qulity and 10 is best
#
# only scores obtained are between 3 to 8

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [raw]
# qulaity has most values concentrated in the categories of 5,6,7
# few observations are present in the categories in 3 and 8

# %% [markdown]
# # Data visulaization

# %% [markdown]
# to check missing values

# %%
sns.heatmap(df.isnull())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e13396ce9ebd> in <module>
# ----> 1 sns.heatmap(df.isnull())
#
# NameError: name 'sns' is not defined

# %% [raw]
# dataset has no missing values

# %% [markdown]
# # To check correlations

# %%
dfcor=df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dfcor)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %% [raw]
# observations:
#     light shades are highly corealted
#     quality is highly correlated with alcohol
#     alcohol is highly negatively correlated with densty with -0.5
#     denisty is highly positively correlated with residual sugar
#     volatile acidity is neagtively correlated with total sulfur dioxide
#     free suplhuric acid is highly correlated with total sulfur dioxide
#
#     hence we can drop volatile acidty from datasets if we are doing the linear regression

# %% [markdown]
# # outliers checking

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['fixed acidity'].plot.box()

# %%
df['volatile acidity'].plot.box()

# %%
df['citric acid'].plot.box()

# %%
df['residual sugar'].plot.box()

# %%
df['chlorides'].plot.box()

# %%
df['free sulfur dioxide'].plot.box()

# %%
df['total sulfur dioxide'].plot.box()

# %%
df['density'].plot.box()

# %%
df['pH'].plot.box()

# %%
df['sulphates'].plot.box()

# %%
df['alcohol'].plot.box()

# %% [raw]
# from the above box plot we can see outliers are presnet in all

# %%
df.shape
# Out:
# (1599, 12)

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
           plt.subplot(nrows,ncol,i+1)
           sns.boxplot(df[collist[i]],color='green',orient='v')
           plt.tight_layout()

# %% [markdown]
# # to check sitribution of skewness

# %%
import seaborn as sns
import numpy as ny
import matplotlib.pyplot as plt

# %%
sns.distplot(df['fixed acidity'])
plt.show()

# %%
sns.distplot(df['citric acid'])

# %%
sns.distplot(df['volatile acidity'])

# %%
sns.distplot(df['chlorides'])

# %%
sns.distplot(df['free sulfur dioxide'])

# %%
sns.distplot(df['total sulfur dioxide'])

# %%
sns.distplot(df['density'])

# %%
sns.distplot(df['pH'])

# %%
sns.distplot(df['sulphates'])

# %%
sns.distplot(df['alcohol'])

# %%
only density and ph data is normal distributed

other independent variables are right skewed/positively skewed

# %% [markdown]
# # bivariate anlaysis

# %% [markdown]
# scatterplot

# %%
import seaborn as sns
sns.scatterplot(x='fixed acidity',y='quality',data=df)

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=df)

# %%
sns.scatterplot(x='density',y='quality',data=df)

# %%
sns.scatterplot(x='pH',y='quality',data=df)

# %%
sns.scatterplot(x='sulphates',y='quality',data=df)

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)

# %%
df.drop('volatile acidity',axis=1,inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            7.4         0.00             1.9      0.076                 11.0
# 1            7.8         0.00             2.6      0.098                 25.0
# 2            7.8         0.04             2.3      0.092                 15.0
# 3           11.2         0.56             1.9      0.075                 17.0
# 4            7.4         0.00             1.9      0.076                 11.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 4                  34.0   0.9978  3.51       0.56      9.4        5

# %%
df.shape
# Out:
# (1599, 11)

# %% [markdown]
# # removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.52835961, 1.39147228, 0.45321841, ..., 0.57920652, 0.96024611,
#         0.78782264],
#        [0.29854743, 1.39147228, 0.04341614, ..., 0.1289504 , 0.58477711,
#         0.78782264],
#        [0.29854743, 1.18607043, 0.16942723, ..., 0.04808883, 0.58477711,
#         0.78782264],
#        ...,
#        [1.1603431 , 0.72391627, 0.16942723, ..., 0.54204194, 0.54162988,
#         0.45084835],
#        [1.39015528, 0.77526673, 0.38227061, ..., 0.30598963, 0.20930812,
#         0.78782264],
#        [1.33270223, 1.02199944, 0.75289408, ..., 0.01092425, 0.54162988,
#         0.45084835]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         109,  142,  144,  147,  151,  151,  151,  151,  163,  164,  169,
#         169,  181,  226,  226,  240,  243,  244,  258,  258,  274,  281,
#         291,  324,  325,  339,  340,  347,  354,  374,  381,  391,  396,
#         396,  400,  400,  442,  442,  451,  459,  467,  480,  480,  494,
#         515,  517,  544,  554,  554,  555,  555,  557,  557,  568,  584,
#         588,  591,  595,  608,  614,  636,  639,  649,  649,  651,  652,
#         652,  652,  672,  684,  690,  692,  692,  695,  723,  730,  754,
#         776,  777,  795,  821,  832,  836,  837,  889,  899,  911,  917,
#         923,  925,  926,  982, 1017, 1018, 1043, 1051, 1051, 1071, 1074,
#        1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186,
#        1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288,
# ...

# %%
z[13][8]
# Out:
# 5.32210116796055

# %%
z[15][8]
# Out:
# 1.6042773232048406

# %%
z[16][9]
# Out:
# 0.07229363170661092

# %%
z[1589][2]
# Out:
# 3.732701384742145

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# ...

# %%
df.shape
# Out:
# (1599, 11)

# %%
df_new.shape
# Out:
# (1458, 11)

# %%
#141 rows are delated as an outliers

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # spliting data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
x.shape
# Out:
# (1458, 10)

# %%
y.shape
# Out:
# (1458,)

# %%
x_train.shape
# Out:
# (1429, 10)

# %%
y_train.shape
# Out:
# (1429,)

# %%
x_test.shape
# Out:
# (29, 10)

# %%
y_test.shape
# Out:
# (29,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=29,random_state=46)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-2.51207516e-02,  3.61716009e-02, -8.05815520e-03, -4.42815480e-02,
#         6.62036236e-02, -1.29903849e-01,  5.55111512e-16, -1.17025616e-01,
#         2.38151969e-01,  2.86006138e-01])

# %%
lm.intercept_
# Out:
# 5.650186567721686

# %%
lm.score(x_train,y_train)
# Out:
# 0.36065934657997745

# %%
#predict the value
pred=lm.predict(x_test)
print('predicted result:',pred)
print('actual result',y_test)
# Out:
# predicted result: [5.67949154 4.90813934 5.25102043 5.45691433 5.07742886 6.08214779
#  5.80704027 5.93715232 6.01521298 6.33500593 5.17920871 5.07943795
#  5.81148805 6.1809401  5.8457997  5.04166045 5.63223682 5.75768448
#  5.73215427 5.23708725 5.3135912  5.82434815 6.07802579 6.09063672
#  5.39130551 5.26959396 6.01689381 6.34598636 6.59438267]
# actual result 659     4
# 1457    5
# 211     6
# 804     6
# 744     5
# 1596    6
# 110     5
# 499     6
# 1298    6
# 1450    7
# 603     6
# 20      6
# 279     7
# 1311    6
# 1416    5
# 1338    5
# 676     6
# 1127    6
# 1468    7
# 1174    6
# 487     6
# 429     6
# 1322    5
# 941     7
# 1028    6
# 1211    5
# 320     7
# 514     7
# 477     6
# Name: quality, dtype: int64

# %%
print('error')
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared error:',mean_squared_error(y_test,pred))

print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absolute error: 0.5990149132795177
# mean squared error: 0.5360097698916567
# root mean squared error: 0.7321268810060567

# %%
#r2 score--> coefficeint of determination
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.06862765190313369

# %%
df=pd.DataFrame(pred)
df.to_csv('wine_pred_submission.csv')

# %% [markdown]
# # modeling

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
model1 = DecisionTreeClassifier(random_state=1)
model1.fit(x_train, y_train)
y_pred1 = model1.predict(x_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.50      1.00      0.67         1
#            5       0.56      0.71      0.63         7
#            6       0.83      0.67      0.74        15
#            7       0.83      0.83      0.83         6
#
#     accuracy                           0.72        29
#    macro avg       0.68      0.80      0.72        29
# weighted avg       0.75      0.72      0.73        29

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(x_train, y_train)
y_pred2 = model2.predict(x_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         1
#            5       0.50      0.86      0.63         7
#            6       0.82      0.60      0.69        15
#            7       0.83      0.83      0.83         6
#
#     accuracy                           0.69        29
#    macro avg       0.54      0.57      0.54        29
# weighted avg       0.72      0.69      0.68        29

# %%
from sklearn.ensemble import GradientBoostingClassifier
model4 = GradientBoostingClassifier(random_state=1)
model4.fit(x_train, y_train)
y_pred4 = model4.predict(x_test)
print(classification_report(y_test, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         1
#            5       0.46      0.86      0.60         7
#            6       0.57      0.53      0.55        15
#            7       0.50      0.17      0.25         6
#
#     accuracy                           0.52        29
#    macro avg       0.38      0.39      0.35        29
# weighted avg       0.51      0.52      0.48        29
