# %% [markdown]
# # crime rates in india

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('crimes in india')
df.head(10)
# Out:
#                    Area_Name  Year           Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Burglary - Property    3. Burglary
# 1             Andhra Pradesh  2001  Burglary - Property    3. Burglary
# 2          Arunachal Pradesh  2001  Burglary - Property    3. Burglary
# 3                      Assam  2001  Burglary - Property    3. Burglary
# 4                      Bihar  2001  Burglary - Property    3. Burglary
# 5                 Chandigarh  2001  Burglary - Property    3. Burglary
# 6               Chhattisgarh  2001  Burglary - Property    3. Burglary
# 7       Dadra & Nagar Haveli  2001  Burglary - Property    3. Burglary
# 8                Daman & Diu  2001  Burglary - Property    3. Burglary
# 9                      Delhi  2001  Burglary - Property    3. Burglary
#
#    Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                        27                     64
# 1                      3321                   7134
# ...

# %%
df.shape
# Out:
# (2449, 8)

# %%
df.dtypes
# Out:
# Area_Name                      object
# Year                            int64
# Group_Name                     object
# Sub_Group_Name                 object
# Cases_Property_Recovered        int64
# Cases_Property_Stolen           int64
# Value_of_Property_Recovered     int64
# Value_of_Property_Stolen        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2449 entries, 0 to 2448
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Area_Name                    2449 non-null   object
#  1   Year                         2449 non-null   int64
#  2   Group_Name                   2449 non-null   object
#  3   Sub_Group_Name               2449 non-null   object
#  4   Cases_Property_Recovered     2449 non-null   int64
#  5   Cases_Property_Stolen        2449 non-null   int64
#  6   Value_of_Property_Recovered  2449 non-null   int64
#  7   Value_of_Property_Stolen     2449 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 153.2+ KB

# %%
df.isnull().any()
# Out:
# Area_Name                      False
# Year                           False
# Group_Name                     False
# Sub_Group_Name                 False
# Cases_Property_Recovered       False
# Cases_Property_Stolen          False
# Value_of_Property_Recovered    False
# Value_of_Property_Stolen       False
# dtype: bool

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#               Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# count  2449.000000               2449.000000            2449.000000
# mean   2005.499388               1232.892201            3419.420988
# std       2.873294               3079.573907            8136.256820
# min    2001.000000                  0.000000               0.000000
# 25%    2003.000000                 13.000000              45.000000
# 50%    2005.000000                113.000000             358.000000
# 75%    2008.000000                722.000000            1875.000000
# max    2010.000000              27960.000000           80663.000000
#
#        Value_of_Property_Recovered  Value_of_Property_Stolen
# count                 2.449000e+03              2.449000e+03
# mean                  5.859924e+07              2.465431e+08
# std                   2.494403e+08              9.670035e+08
# min                   0.000000e+00              0.000000e+00
# ...

# %% [raw]
# Value_of_Property_Stolen
# count-2.449000e+03
# mean-2.465431e+08
# std-9.670035e+08
# min-0.000000e+00
# max-2.377625e+10
#
# Value_of_Property_Recovered
# count-2.449000e+03
# mean-5.859924e+07
# std-2.494403e+08
# min	-0.000000e+00
# max-7.470011e+09
#
# Cases_Property_Stolen
# count-2449.000000
# mean-3419.420988
# std-8136.256820
# min-0.000000
# max-80663.000000
#
# cases_Property_Recovered
# count-2449.000000
# mean-1232.892201
# std-3079.573907
# min-0.000000
# max-27960.000000

# %%
dfcor=df.corr()
dfcor
# Out:
#                                  Year  Cases_Property_Recovered  \
# Year                         1.000000                  0.022467
# Cases_Property_Recovered     0.022467                  1.000000
# Cases_Property_Stolen        0.028893                  0.935765
# Value_of_Property_Recovered  0.099033                  0.495588
# Value_of_Property_Stolen     0.100732                  0.579084
#
#                              Cases_Property_Stolen  \
# Year                                      0.028893
# Cases_Property_Recovered                  0.935765
# Cases_Property_Stolen                     1.000000
# Value_of_Property_Recovered               0.508971
# Value_of_Property_Stolen                  0.643448
#
#                              Value_of_Property_Recovered  \
# Year                                            0.099033
# Cases_Property_Recovered                        0.495588
# Cases_Property_Stolen                           0.508971
# ...

# %% [raw]
# using the heatmap for better uderstanding of correlation

# %%
plt.figure(figsize=(10,8))
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %% [raw]
# there is a good corelation between value of property stolen and cases of property stolen

# %% [markdown]
# # EDA

# %% [raw]
# biivariate analysis

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
sns.scatterplot(x='Value_of_Property_Recovered',y='Value_of_Property_Stolen',data=df)

# %%
sns.scatterplot(x='Cases_Property_Stolen',y='Value_of_Property_Stolen',data=df)

# %%
sns.scatterplot(x='Cases_Property_Recovered',y='Value_of_Property_Stolen',data=df)

# %%
sns.scatterplot(x='Sub_Group_Name',y='Value_of_Property_Stolen',data=df)

# %%
sns.scatterplot(x='Group_Name',y='Value_of_Property_Stolen',data=df)

# %%
sns.scatterplot(x='Year',y='Value_of_Property_Stolen',data=df)

# %%
sns.scatterplot(x='Area_Name',y='Value_of_Property_Stolen',data=df)

# %% [markdown]
# # checking for outliers

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %%
sns.boxplot(df['Value_of_Property_Stolen'])

# %%
sns.boxplot(df['Value_of_Property_Recovered'])

# %%
sns.boxplot(df['Cases_Property_Stolen'])

# %%
sns.boxplot(df['Cases_Property_Recovered'])

# %% [markdown]
# # sns.boxplot(df['Year'])

# %% [raw]
# there are huge outliers present in cases of propert stolen,cases of property recovered,value of propert stolen and value of property revovered.,

# %% [markdown]
# # checking for skewness

# %%
df.skew()
# Out:
# Year                            0.000582
# Cases_Property_Recovered        4.180588
# Cases_Property_Stolen           4.123731
# Value_of_Property_Recovered    20.650682
# Value_of_Property_Stolen       11.875169
# dtype: float64

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %%
sns.distplot(df['Year'])
plt.show()

# %%
sns.distplot(df['Cases_Property_Recovered'])
plt.show()

# %%
sns.distplot(df['Cases_Property_Stolen'])
plt.show()

# %%
sns.distplot(df['Value_of_Property_Recovered'])
plt.show()

# %%
sns.distplot(df['Value_of_Property_Stolen'])
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.56625315, 0.39165758, 0.41248775, 0.23194005, 0.25364046],
#        [1.56625315, 0.67818936, 0.45663967, 0.02853291, 0.10294076],
#        [1.56625315, 0.37899091, 0.38986831, 0.23166235, 0.24990658],
#        ...,
#        [1.56667957, 2.56487451, 3.89061496, 2.08105317, 1.2371947 ],
#        [1.56667957, 0.08733257, 0.14572587, 0.0459665 , 0.12737224],
#        [1.56667957, 1.07670247, 2.50037989, 4.44943959, 4.93234976]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 405,  615,  685, 1034, 1034, 1166, 1280, 1315, 1339, 1350, 1385,
#        1770, 1770, 1780, 1805, 1805, 1815, 1821, 1840, 1840, 1850, 1856,
#        1875, 1875, 1885, 1891, 1910, 1910, 1920, 1926, 1945, 1945, 1955,
#        1961, 1980, 1980, 1990, 1996, 2015, 2015, 2015, 2025, 2031, 2050,
#        2050, 2060, 2066, 2085, 2085, 2085, 2085, 2095, 2101, 2119, 2119,
#        2120, 2120, 2120, 2120, 2130, 2132, 2132, 2136, 2136, 2146, 2154,
#        2154, 2155, 2155, 2155, 2155, 2165, 2167, 2171, 2171, 2181, 2181,
#        2189, 2189, 2190, 2190, 2190, 2200, 2206, 2206, 2216, 2216, 2224,
#        2224, 2225, 2225, 2225, 2225, 2235, 2241, 2241, 2249, 2251, 2259,
#        2259, 2260, 2260, 2260, 2260, 2270, 2276, 2276, 2294, 2294, 2295,
#        2295, 2295, 2295, 2305, 2307, 2311, 2311, 2328, 2328, 2329, 2329,
#        2329, 2329, 2339, 2345, 2345, 2353, 2355, 2363, 2363, 2364, 2364,
#        2364, 2364, 2374, 2376, 2376, 2380, 2380, 2388, 2395, 2395, 2398,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (2449, 5)
# (2350, 5)

# %% [markdown]
# # data cleaning:

# %%
df
# Out:
#       Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# 0     2001                        27                     64
# 1     2001                      3321                   7134
# 2     2001                        66                    248
# 3     2001                       539                   2423
# 4     2001                       367                   3231
# ...    ...                       ...                    ...
# 2444  2010                     16125                  21509
# 2445  2010                       192                    879
# 2446  2010                      9130                  35068
# 2447  2010                       964                   2234
# 2448  2010                      4548                  23759
#
#       Value_of_Property_Recovered  Value_of_Property_Stolen
# 0                          755858                   1321961
# 1                        51483437                 147019348
# 2                          825115                   4931904
# ...

# %% [markdown]
# # percentage of data loss

# %%
loss_percent=(2449-2350)/2449*2350
print(loss_percent)
# Out:
# 94.99795835034709

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
scaled=sc.fit_transform(x)

# %%
#finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score


best_rstate=0
accu=0
for i in range(30,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        
print(f"best accuracy {accu*100}found on random_state {best_rstate}")
# Out:
# best accuracy 58.62213535829125found on random_state 154

# %%
#spliting the data into training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25,random_state=154)

# %% [markdown]
# # finding the best model

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(LinearRegression(),x_train,y_train,cv=5).mean()
print(f"accuracy={r2score*100}, Cross_val_score = {cvscore*100} $ difference = {(r2score*100)-(cvscore*100)}")
# Out:
# accuracy=58.62213535829125, Cross_val_score = 41.95924191790768 $ difference = 16.66289344038357

# %%
#randomo forestregressor
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(x_train,y_train)
y_pred=RF.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(RandomForestRegressor(),x_train,y_train,cv=5).mean()
print(f"accuracy={r2score*100}, Cross_val_score = {cvscore*100} $ difference = {(r2score*100)-(cvscore*100)}")
# Out:
# accuracy=55.17964747253043, Cross_val_score = 44.430556003543096 $ difference = 10.74909146898733

# %%
#SGDRegressor
from sklearn.linear_model import SGDRegressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)
y_pred=SGD.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(SGDRegressor(),x_train,y_train,cv=5).mean()
print(f"accuracy={r2score*100}, Cross_val_score = {cvscore*100} $ difference = {(r2score*100)-(cvscore*100)}")
# Out:
# accuracy=-2.3793404903309326e+34, Cross_val_score = -3.159556631320049e+34 $ difference = 7.802161409891163e+33

# %%
#adaBoostRegessor
from sklearn.ensemble import AdaBoostRegressor
ADB=AdaBoostRegressor()
ADB.fit(x_train,y_train)
y_pred=ADB.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(AdaBoostRegressor(),x_train,y_train,cv=5).mean()
print(f"accuracy={r2score*100}, Cross_val_score = {cvscore*100} $ difference = {(r2score*100)-(cvscore*100)}")
# Out:
# accuracy=-100.07374653474308, Cross_val_score = -39.762245669266925 $ difference = -60.311500865476155

# %% [markdown]
# our best performing model is linear regression and we will use this model for prediction
